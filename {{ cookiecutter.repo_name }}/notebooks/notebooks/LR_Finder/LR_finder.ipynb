# %% [markdown]
# # LR Finder
#
# How to run:
#
#     -> set your files,params,model in src/config.yaml
#     -> run each cell (separated to timeseries, images, structureddata)
#     -> see your LR_Finder result in folder /reports
#
#
# for more infos:
#
# https://www.avanwyk.com/finding-a-learning-rate-in-tensorflow-2/

# %%
import os
os.chdir("../../../")
os.getcwd()
# Out:
# 'C:\\Users\\Tom\\Desktop\\MA\\{{ cookiecutter.repo_name }}'

# %% [markdown]
# #### TIMESERIES

# %%
#this updated model.py has always added Callback "LR_Finder")
# !python notebooks/notebooks/LR_Finder/LR_Finder_py/model/model_timeseries.py
# Out:
# Due to missing textual information 0 rows deleted.
# Due to missing numerical data(NaN) 0 results replaced by median value.
# Number classes: 4
# 2022-03-14 03:10:29.985415: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-14 03:11:03.765472: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# Name classes: Gebohrt GeoelterStift Referenz Versatz
# Number samples of each class: 72 72 144 72
# Using 216 samples for training, 72 for validation , 72 for testing.
# Distribution of labels for Train-/Test-/Valset:
# Kategorie
# Referenz         87
# Gebohrt          43
# GeoelterStift    43
# Versatz          43
# ...

# %% [markdown]
# -> after executing cell, LR_Finder_TimeSeries.svg should be saved in /reports folder

# %% [markdown]
# #### Images

# %%
#this updated model.py has always added Callback "LR_Finder")
# !python notebooks/notebooks/LR_Finder/LR_Finder_py/model/model_images.py

# %% [markdown]
# -> after executing cell, LR_Finder_Images.svg should be saved in /reports folder

# %% [markdown]
# #### StructuredData

# %%
#this updated model.py has always added Callback "LR_Finder")
# !python notebooks/notebooks/LR_Finder/LR_Finder_py/model/model_structureddata.py

# %% [markdown]
# -> after executing cell, LR_Finder_StructuredData.svg should be saved in /reports folder
